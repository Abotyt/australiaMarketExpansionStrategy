# %% [markdown]
# # Project: Australian Market Expansion Strategy -
# ## Workforce-Based Business Expansion Analytics

# %% [markdown]
# ### Description:

# %% [markdown]
# Goal: explore and clean the datasets
# Tech: Python\
# Library: pandas, numpy, re, string\
# Data Source: Australian Bureau of Statistics\
# Datasets: EmploymentByState_NewSouthWales, EmploymentByState_NorthernTerritory\
# Import Funtions Files: Functions.py

# %% [markdown]
# ## Part1. Library and datasets

# %% [markdown]
# ### Library:

# %%
# install
#!pip install pandas openpyxl

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import re
import string
from Functions import extract_matadata, melt_and_update_columns, merge_metadata_and_melted_dataset

# %% [markdown]
# ### Files:

# %% [markdown]
# Location:

# %%
fileLocation = '/Users/abbottting/Desktop/Project/AMES/OriginalData'

# %%
#CPIMonthly_path = fileLocation + '/' + "CPI_MonthlyPercentageChange.xlsx"
#EmployPopulationRatial_Path = fileLocation + '/' + 'EmploymentToPopulationRatio.csv'
EmploymentByState_NewSouthWales_Path = fileLocation + '/'  + 'EmploymentByState_NewSouthWales.xlsx'
EmploymentByState_NorthernTerritory_Path = fileLocation + '/'  + 'EmploymentByState_NorthernTerritory.xlsx'

# %% [markdown]
# Read files

# %%
#CPI_MonthlyOriginal = pd.read_excel(CPIMonthly_path, sheet_name = "Data1")
#EmployPopulationRatial_Original = pd.read_csv(EmployPopulationRatial_Path)
EmploymentByState_NewSouthWales_Original = pd.read_excel(EmploymentByState_NewSouthWales_Path, sheet_name = 'Data1')
EmploymentByState_NorthernTerritory_Original = pd.read_excel(EmploymentByState_NorthernTerritory_Path, sheet_name = 'Data1')
#The following dataset is not required 
#LabourForce_CurrentOriginal = pd.read_excel(LabourForce_Path, sheet_name = "Data 1")
#LabourForce_PreviousOriginal = pd.read_excel(LabourForce_Path, sheet_name = "Data 2")

# %% [markdown]
# ## Part2. Data Extraction and transformation

# %% [markdown]
# ### EmploymentByState_NewSouthWales

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
EmploymentByState_NewSouthWales_Original.head(10)
# Out:
#             Unnamed: 0 Employed total ;  Persons ;  \
# 0                 Unit                         000
# 1          Series Type                       Trend
# 2            Data Type                       STOCK
# 3            Frequency                       Month
# 4     Collection Month                           1
# 5         Series Start         1978-02-01 00:00:00
# 6           Series End         2026-01-01 00:00:00
# 7              No. Obs                         576
# 8            Series ID                  A84423937R
# 9  1978-02-01 00:00:00                 2108.211696
#
#   Employed total ;  Persons ;.1 Employed total ;  Persons ;.2  \
# 0                           000                           000
# 1           Seasonally Adjusted                      Original
# 2                         STOCK                         STOCK
# 3                         Month                         Month
# 4                             1                             1
# 5           1978-02-01 00:00:00           1978-02-01 00:00:00
# 6           2026-01-01 00:00:00           2026-01-01 00:00:00
# 7                           576                           576
# 8                    A84423265K                    A84423601K
# 9                   2113.937155                   2114.116622
#
#   Employed total ;  > Males ; Employed total ;  > Males ;.1  \
# 0                         000                           000
# 1                       Trend           Seasonally Adjusted
# 2                       STOCK                         STOCK
# 3                       Month                         Month
# 4                           1                             1
# 5         1978-02-01 00:00:00           1978-02-01 00:00:00
# 6         2026-01-01 00:00:00           2026-01-01 00:00:00
# 7                         576                           576
# 8                  A84423825W                    A84423153T
# 9                 1363.006258                    1365.43433
#
#   Employed total ;  > Males ;.2 Employed total ;  > Females ;  \
# 0                           000                           000
# 1                      Original                         Trend
# 2                         STOCK                         STOCK
# 3                         Month                         Month
# 4                             1                             1
# 5           1978-02-01 00:00:00           1978-02-01 00:00:00
# 6           2026-01-01 00:00:00           2026-01-01 00:00:00
# 7                           576                           576
# 8                    A84423489W                    A84424049K
# 9                   1369.400359                    745.205437
#
#   Employed total ;  > Females ;.1 Employed total ;  > Females ;.2  ...  \
# 0                             000                             000  ...
# 1             Seasonally Adjusted                        Original  ...
# 2                           STOCK                           STOCK  ...
# 3                           Month                           Month  ...
# 4                               1                               1  ...
# 5             1978-02-01 00:00:00             1978-02-01 00:00:00  ...
# 6             2026-01-01 00:00:00             2026-01-01 00:00:00  ...
# 7                             576                             576  ...
# 8                      A84423377C                      A84423713C  ...
# 9                      748.502825                      744.716262  ...
#
#   Participation rate ;  > Males ;.2 Participation rate ;  > Females ;  \
# 0                           Percent                           Percent
# 1                          Original                             Trend
# 2                           PERCENT                           PERCENT
# 3                             Month                             Month
# 4                                 1                                 1
# 5               1978-02-01 00:00:00               1978-02-01 00:00:00
# 6               2026-01-01 00:00:00               2026-01-01 00:00:00
# 7                               576                               576
# 8                        A84423495T                        A84424055F
# 9                         79.757877                         42.768707
#
#   Participation rate ;  > Females ;.1 Participation rate ;  > Females ;.2  \
# 0                             Percent                             Percent
# 1                 Seasonally Adjusted                            Original
# 2                             PERCENT                             PERCENT
# 3                               Month                               Month
# 4                                   1                                   1
# 5                 1978-02-01 00:00:00                 1978-02-01 00:00:00
# 6                 2026-01-01 00:00:00                 2026-01-01 00:00:00
# 7                                 576                                 576
# 8                          A84423383X                          A84423719T
# 9                           43.022597                           43.388591
#
#   Not in the labour force (NILF) ;  Persons ;  \
# 0                                         000
# 1                                    Original
# 2                                       STOCK
# 3                                       Month
# 4                                           1
# 5                         1978-02-01 00:00:00
# 6                         2026-01-01 00:00:00
# 7                                         576
# 8                                  A84423604T
# 9                                  1447.67271
#
#   Not in the labour force (NILF) ;  > Males ;  \
# 0                                         000
# 1                                    Original
# 2                                       STOCK
# 3                                       Month
# 4                                           1
# 5                         1978-02-01 00:00:00
# 6                         2026-01-01 00:00:00
# 7                                         576
# 8                                  A84423492K
# 9                                  371.382833
#
#   Not in the labour force (NILF) ;  > Females ;  \
# 0                                           000
# 1                                      Original
# 2                                         STOCK
# 3                                         Month
# 4                                             1
# 5                           1978-02-01 00:00:00
# 6                           2026-01-01 00:00:00
# 7                                           576
# 8                                    A84423716K
# 9                                   1076.289877
#
#   Civilian population aged 15 years and over ;  Persons ;  \
# 0                                                000
# 1                                           Original
# 2                                              STOCK
# 3                                              Month
# 4                                                  1
# 5                                1978-02-01 00:00:00
# 6                                2026-01-01 00:00:00
# 7                                                576
# 8                                         A84423605V
# 9                                        3735.891949
#
#   Civilian population aged 15 years and over ;  > Males ;  \
# 0                                                000
# 1                                           Original
# 2                                              STOCK
# 3                                              Month
# 4                                                  1
# 5                                1978-02-01 00:00:00
# 6                                2026-01-01 00:00:00
# 7                                                576
# 8                                         A84423493L
# 9                                        1834.702955
#
#   Civilian population aged 15 years and over ;  > Females ;
# 0                                                000
# 1                                           Original
# 2                                              STOCK
# 3                                              Month
# 4                                                  1
# 5                                1978-02-01 00:00:00
# 6                                2026-01-01 00:00:00
# 7                                                576
# 8                                         A84423717L
# 9                                        1901.188995
#
# [10 rows x 85 columns]

# %%
EmploymentByState_NewSouthWales_Original.columns
# Out:
# Index(['Unnamed: 0', 'Employed total ;  Persons ;',
#        'Employed total ;  Persons ;.1', 'Employed total ;  Persons ;.2',
#        'Employed total ;  > Males ;', 'Employed total ;  > Males ;.1',
#        'Employed total ;  > Males ;.2', 'Employed total ;  > Females ;',
#        'Employed total ;  > Females ;.1', 'Employed total ;  > Females ;.2',
#        '> Employed full-time ;  Persons ;',
#        '> Employed full-time ;  Persons ;.1',
#        '> Employed full-time ;  Persons ;.2',
#        '> Employed full-time ;  > Males ;',
#        '> Employed full-time ;  > Males ;.1',
#        '> Employed full-time ;  > Males ;.2',
#        '> Employed full-time ;  > Females ;',
#        '> Employed full-time ;  > Females ;.1',
#        '> Employed full-time ;  > Females ;.2',
#        '> Employed part-time ;  Persons ;',
#        '> Employed part-time ;  > Males ;',
#        '> Employed part-time ;  > Females ;',
#        'Employment to population ratio ;  Persons ;',
#        'Employment to population ratio ;  Persons ;.1',
#        'Employment to population ratio ;  Persons ;.2',
#        'Employment to population ratio ;  > Males ;',
#        'Employment to population ratio ;  > Males ;.1',
#        'Employment to population ratio ;  > Males ;.2',
#        'Employment to population ratio ;  > Females ;',
#        'Employment to population ratio ;  > Females ;.1',
#        'Employment to population ratio ;  > Females ;.2',
#        'Unemployed total ;  Persons ;', 'Unemployed total ;  Persons ;.1',
#        'Unemployed total ;  Persons ;.2', 'Unemployed total ;  > Males ;',
#        'Unemployed total ;  > Males ;.1', 'Unemployed total ;  > Males ;.2',
#        'Unemployed total ;  > Females ;', 'Unemployed total ;  > Females ;.1',
#        'Unemployed total ;  > Females ;.2',
#        '> Unemployed looked for full-time work ;  Persons ;',
#        '> Unemployed looked for full-time work ;  > Males ;',
#        '> Unemployed looked for full-time work ;  > Females ;',
#        '> Unemployed looked for only part-time work ;  Persons ;',
#        '> Unemployed looked for only part-time work ;  > Males ;',
#        '> Unemployed looked for only part-time work ;  > Females ;',
#        'Unemployment rate ;  Persons ;', 'Unemployment rate ;  Persons ;.1',
#        'Unemployment rate ;  Persons ;.2', 'Unemployment rate ;  > Males ;',
#        'Unemployment rate ;  > Males ;.1', 'Unemployment rate ;  > Males ;.2',
#        'Unemployment rate ;  > Females ;',
#        'Unemployment rate ;  > Females ;.1',
#        'Unemployment rate ;  > Females ;.2',
#        '> Unemployment rate looked for full-time work ;  Persons ;',
#        '> Unemployment rate looked for full-time work ;  > Males ;',
#        '> Unemployment rate looked for full-time work ;  > Females ;',
#        '> Unemployment rate looked for only part-time work ;  Persons ;',
#        '> Unemployment rate looked for only part-time work ;  > Males ;',
#        '> Unemployment rate looked for only part-time work ;  > Females ;',
#        'Labour force total ;  Persons ;', 'Labour force total ;  Persons ;.1',
#        'Labour force total ;  Persons ;.2', 'Labour force total ;  > Males ;',
#        'Labour force total ;  > Males ;.1',
#        'Labour force total ;  > Males ;.2',
#        'Labour force total ;  > Females ;',
#        'Labour force total ;  > Females ;.1',
#        'Labour force total ;  > Females ;.2',
#        'Participation rate ;  Persons ;', 'Participation rate ;  Persons ;.1',
#        'Participation rate ;  Persons ;.2', 'Participation rate ;  > Males ;',
#        'Participation rate ;  > Males ;.1',
#        'Participation rate ;  > Males ;.2',
#        'Participation rate ;  > Females ;',
#        'Participation rate ;  > Females ;.1',
#        'Participation rate ;  > Females ;.2',
#        'Not in the labour force (NILF) ;  Persons ;',
#        'Not in the labour force (NILF) ;  > Males ;',
#        'Not in the labour force (NILF) ;  > Females ;',
#        'Civilian population aged 15 years and over ;  Persons ;',
#        'Civilian population aged 15 years and over ;  > Males ;',
#        'Civilian population aged 15 years and over ;  > Females ;'],
#       dtype='str')

# %% [markdown]
# #### Data processing plan

# %% [markdown]
# Step 1. Turn the first to eighth row index into columns.\
# Step 2. Turn the rest of the index into variables of a column called date.\
# Step 3. Consistently transform column by column.\
# Step 4. Use the code to develop automation and functions in other files for later use.

# %% [markdown]
# #### Step1. Turn the first to eighth row index into mata data

# %%
# Extract the first eight rows into metadata and transpose the matrix
mata_data = EmploymentByState_NewSouthWales_Original.iloc[:9].T
mata_data.head()
# Out:
#                                   0                    1          2  \
# Unnamed: 0                     Unit          Series Type  Data Type
# Employed total ;  Persons ;     000                Trend      STOCK
# Employed total ;  Persons ;.1   000  Seasonally Adjusted      STOCK
# Employed total ;  Persons ;.2   000             Original      STOCK
# Employed total ;  > Males ;     000                Trend      STOCK
#
#                                        3                 4  \
# Unnamed: 0                     Frequency  Collection Month
# Employed total ;  Persons ;        Month                 1
# Employed total ;  Persons ;.1      Month                 1
# Employed total ;  Persons ;.2      Month                 1
# Employed total ;  > Males ;        Month                 1
#
#                                                  5                    6  \
# Unnamed: 0                            Series Start           Series End
# Employed total ;  Persons ;    1978-02-01 00:00:00  2026-01-01 00:00:00
# Employed total ;  Persons ;.1  1978-02-01 00:00:00  2026-01-01 00:00:00
# Employed total ;  Persons ;.2  1978-02-01 00:00:00  2026-01-01 00:00:00
# Employed total ;  > Males ;    1978-02-01 00:00:00  2026-01-01 00:00:00
#
#                                      7           8
# Unnamed: 0                     No. Obs   Series ID
# Employed total ;  Persons ;        576  A84423937R
# Employed total ;  Persons ;.1      576  A84423265K
# Employed total ;  Persons ;.2      576  A84423601K
# Employed total ;  > Males ;        576  A84423825W

# %%
# reset index
mata_data_reindex = mata_data.reset_index()
mata_data_reindex.head()
# Out:
#                            index     0                    1          2  \
# 0                     Unnamed: 0  Unit          Series Type  Data Type
# 1    Employed total ;  Persons ;   000                Trend      STOCK
# 2  Employed total ;  Persons ;.1   000  Seasonally Adjusted      STOCK
# 3  Employed total ;  Persons ;.2   000             Original      STOCK
# 4    Employed total ;  > Males ;   000                Trend      STOCK
#
#            3                 4                    5                    6  \
# 0  Frequency  Collection Month         Series Start           Series End
# 1      Month                 1  1978-02-01 00:00:00  2026-01-01 00:00:00
# 2      Month                 1  1978-02-01 00:00:00  2026-01-01 00:00:00
# 3      Month                 1  1978-02-01 00:00:00  2026-01-01 00:00:00
# 4      Month                 1  1978-02-01 00:00:00  2026-01-01 00:00:00
#
#          7           8
# 0  No. Obs   Series ID
# 1      576  A84423937R
# 2      576  A84423265K
# 3      576  A84423601K
# 4      576  A84423825W

# %%
# extract first row and use it as column names
new_columns = list(mata_data_reindex.iloc[0])
new_columns
# Out:
# ['Unnamed: 0',
#  'Unit',
#  'Series Type',
#  'Data Type',
#  'Frequency',
#  'Collection Month',
#  'Series Start',
#  'Series End',
#  'No. Obs',
#  'Series ID']

# %%
# update column format
for i in range(len(new_columns)):
    column_name = new_columns[i].lower()
    punctuation_removed = column_name.translate(str.maketrans('','',string.punctuation))
    new_columns[i] = punctuation_removed.replace(' ', '_')

# %%
# assign, remove first row, reset index
mata_data_reindex.columns = new_columns
mata_data_updated_columns = mata_data_reindex.iloc[1:].reset_index(drop = True)
mata_data_updated_columns.head(5)
# Out:
#                        unnamed_0 unit          series_type data_type  \
# 0    Employed total ;  Persons ;  000                Trend     STOCK
# 1  Employed total ;  Persons ;.1  000  Seasonally Adjusted     STOCK
# 2  Employed total ;  Persons ;.2  000             Original     STOCK
# 3    Employed total ;  > Males ;  000                Trend     STOCK
# 4  Employed total ;  > Males ;.1  000  Seasonally Adjusted     STOCK
#
#   frequency collection_month         series_start           series_end no_obs  \
# 0     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 1     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 2     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 3     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 4     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
#
#     series_id
# 0  A84423937R
# 1  A84423265K
# 2  A84423601K
# 3  A84423825W
# 4  A84423153T

# %%
# update the first column name
first_column = mata_data_updated_columns.columns[0]
print(f'original column name: {first_column}')
mata_data_updated_columns.rename(columns={first_column : 'variable'}, inplace = True)
print(f'new column name: {mata_data_updated_columns.columns[0]}')
# assign values to a list in first column
variables_original = list(mata_data_updated_columns['variable'])
# Out:
# original column name: unnamed_0
# new column name: variable

# %%
# Split the variable with genders
variables = []
genders = []
for i, o in enumerate(variables_original):
    splited_object = o.split(';')
    #get the variable and gender from the string
    one_variable = splited_object[0].strip()
    strip_chars = string.whitespace + string.punctuation + string.digits
    one_gender = splited_object[1].strip(strip_chars)
    variables.append(one_variable)
    genders.append(one_gender)

# add gender and variable to the dataset
mata_data_updated_columns.insert(1, 'gender', genders)
mata_data_updated_columns['variable'] = variables

# %%
mata_data_updated_columns.head()
# Out:
#          variable   gender unit          series_type data_type frequency  \
# 0  Employed total  Persons  000                Trend     STOCK     Month
# 1  Employed total  Persons  000  Seasonally Adjusted     STOCK     Month
# 2  Employed total  Persons  000             Original     STOCK     Month
# 3  Employed total    Males  000                Trend     STOCK     Month
# 4  Employed total    Males  000  Seasonally Adjusted     STOCK     Month
#
#   collection_month         series_start           series_end no_obs  \
# 0                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 1                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 2                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 3                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 4                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
#
#     series_id
# 0  A84423937R
# 1  A84423265K
# 2  A84423601K
# 3  A84423825W
# 4  A84423153T

# %% [markdown]
# #### Step2. use series ID as column, prepare to melt the rest of dataset including series id, date, and values

# %%
# check if series_id has no duplicate
duplicate_rows = mata_data_updated_columns[mata_data_updated_columns.duplicated(subset=['series_id'], keep=False)]
duplicate_rows.shape
# Out:
# (0, 11)

# %%
value = EmploymentByState_NewSouthWales_Original.iloc[9:]

# %%
#check data
value.head().iloc[:, :5]
# Out:
#              Unnamed: 0 Employed total ;  Persons ;  \
# 9   1978-02-01 00:00:00                 2108.211696
# 10  1978-03-01 00:00:00                 2109.021527
# 11  1978-04-01 00:00:00                 2109.854462
# 12  1978-05-01 00:00:00                 2111.157961
# 13  1978-06-01 00:00:00                 2112.979788
#
#    Employed total ;  Persons ;.1 Employed total ;  Persons ;.2  \
# 9                    2113.937155                   2114.116622
# 10                   2094.809924                   2110.179431
# 11                   2107.530544                   2115.063279
# 12                   2111.430838                   2111.268984
# 13                   2112.439636                   2113.247138
#
#    Employed total ;  > Males ;
# 9                  1363.006258
# 10                 1361.723258
# 11                 1360.306263
# 12                 1358.992234
# 13                  1357.54763

# %%
# Get series ID
series_id = EmploymentByState_NewSouthWales_Original.loc[8]

# %%
# use series ID as new columnnames
value_series_id = value.rename(columns = series_id)
value_series_id.head().iloc[:, :5]
# Out:
#               Series ID   A84423937R   A84423265K   A84423601K   A84423825W
# 9   1978-02-01 00:00:00  2108.211696  2113.937155  2114.116622  1363.006258
# 10  1978-03-01 00:00:00  2109.021527  2094.809924  2110.179431  1361.723258
# 11  1978-04-01 00:00:00  2109.854462  2107.530544  2115.063279  1360.306263
# 12  1978-05-01 00:00:00  2111.157961  2111.430838  2111.268984  1358.992234
# 13  1978-06-01 00:00:00  2112.979788  2112.439636  2113.247138   1357.54763

# %%
# update the first column name to 'date'
value_date = value_series_id.rename(columns = {'Series ID': 'date'})

# %%
#melt the data set
value_melted = pd.melt(value_date, id_vars = 'date', var_name = 'series_id', value_name='value')
value_melted.head()
# Out:
#         date   series_id        value
# 0 1978-02-01  A84423937R  2108.211696
# 1 1978-03-01  A84423937R  2109.021527
# 2 1978-04-01  A84423937R  2109.854462
# 3 1978-05-01  A84423937R  2111.157961
# 4 1978-06-01  A84423937R  2112.979788

# %% [markdown]
# #### Step3. join part of metadata and values by series_id

# %%
mata_data_updated_columns.head()
# Out:
#          variable   gender unit          series_type data_type frequency  \
# 0  Employed total  Persons  000                Trend     STOCK     Month
# 1  Employed total  Persons  000  Seasonally Adjusted     STOCK     Month
# 2  Employed total  Persons  000             Original     STOCK     Month
# 3  Employed total    Males  000                Trend     STOCK     Month
# 4  Employed total    Males  000  Seasonally Adjusted     STOCK     Month
#
#   collection_month         series_start           series_end no_obs  \
# 0                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 1                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 2                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 3                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 4                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
#
#     series_id
# 0  A84423937R
# 1  A84423265K
# 2  A84423601K
# 3  A84423825W
# 4  A84423153T

# %%
# analys the values in unit, data_type, frequency, collection_month, no_obs
unit_values = set(mata_data_updated_columns['unit'])
data_type_values = set(mata_data_updated_columns['data_type'])
frequency_values = set(mata_data_updated_columns['frequency'])
collection_month_values = set(mata_data_updated_columns['collection_month'])
no_obs_values = set(mata_data_updated_columns['no_obs'])
print(unit_values, data_type_values, frequency_values, collection_month_values, no_obs_values)
# Out:
# {'000', 'Percent'} {'PERCENT', 'STOCK'} {'Month'} {1} {576}

# %%
# select column to merge
selected_matadata = mata_data_updated_columns[['variable', 'gender', 'series_type', 'series_id']]
selected_matadata.head()
# Out:
#          variable   gender          series_type   series_id
# 0  Employed total  Persons                Trend  A84423937R
# 1  Employed total  Persons  Seasonally Adjusted  A84423265K
# 2  Employed total  Persons             Original  A84423601K
# 3  Employed total    Males                Trend  A84423825W
# 4  Employed total    Males  Seasonally Adjusted  A84423153T

# %%
# Merge df1 and df2 using the shared column 'series_id'
final_dataset = pd.merge(value_melted, selected_matadata, on='series_id', how='left')
final_dataset = final_dataset[['date','series_id', 'variable', 'gender', 'series_type', 'value']]
final_dataset.head()
# Out:
#         date   series_id        variable   gender series_type        value
# 0 1978-02-01  A84423937R  Employed total  Persons       Trend  2108.211696
# 1 1978-03-01  A84423937R  Employed total  Persons       Trend  2109.021527
# 2 1978-04-01  A84423937R  Employed total  Persons       Trend  2109.854462
# 3 1978-05-01  A84423937R  Employed total  Persons       Trend  2111.157961
# 4 1978-06-01  A84423937R  Employed total  Persons       Trend  2112.979788

# %%
final_dataset.shape
# Out:
# (48384, 6)

# %% [markdown]
# ### EmploymentByState_NorthernTerritory

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
EmploymentByState_NorthernTerritory_Original.head()
# Out:
#          Unnamed: 0 Employed total ;  Persons ; Employed total ;  > Males ;  \
# 0              Unit                         000                         000
# 1       Series Type         Seasonally Adjusted         Seasonally Adjusted
# 2         Data Type                       STOCK                       STOCK
# 3         Frequency                       Month                       Month
# 4  Collection Month                           1                           1
#
#   Employed total ;  > Females ; > Employed full-time ;  Persons ;  \
# 0                           000                               000
# 1           Seasonally Adjusted               Seasonally Adjusted
# 2                         STOCK                             STOCK
# 3                         Month                             Month
# 4                             1                                 1
#
#   > Employed full-time ;  > Males ; > Employed full-time ;  > Females ;  \
# 0                               000                                 000
# 1               Seasonally Adjusted                 Seasonally Adjusted
# 2                             STOCK                               STOCK
# 3                             Month                               Month
# 4                                 1                                   1
#
#   Employment to population ratio ;  Persons ;  \
# 0                                     Percent
# 1                         Seasonally Adjusted
# 2                                     PERCENT
# 3                                       Month
# 4                                           1
#
#   Employment to population ratio ;  > Males ;  \
# 0                                     Percent
# 1                         Seasonally Adjusted
# 2                                     PERCENT
# 3                                       Month
# 4                                           1
#
#   Employment to population ratio ;  > Females ;  ...  \
# 0                                       Percent  ...
# 1                           Seasonally Adjusted  ...
# 2                                       PERCENT  ...
# 3                                         Month  ...
# 4                                             1  ...
#
#   Unemployed total ;  > Females ; Unemployment rate ;  Persons ;  \
# 0                             000                        Percent
# 1             Seasonally Adjusted            Seasonally Adjusted
# 2                           STOCK                        PERCENT
# 3                           Month                          Month
# 4                               1                              1
#
#   Unemployment rate ;  > Males ; Unemployment rate ;  > Females ;  \
# 0                        Percent                          Percent
# 1            Seasonally Adjusted              Seasonally Adjusted
# 2                        PERCENT                          PERCENT
# 3                          Month                            Month
# 4                              1                                1
#
#   Labour force total ;  Persons ; Labour force total ;  > Males ;  \
# 0                             000                             000
# 1             Seasonally Adjusted             Seasonally Adjusted
# 2                           STOCK                           STOCK
# 3                           Month                           Month
# 4                               1                               1
#
#   Labour force total ;  > Females ; Participation rate ;  Persons ;  \
# 0                               000                         Percent
# 1               Seasonally Adjusted             Seasonally Adjusted
# 2                             STOCK                         PERCENT
# 3                             Month                           Month
# 4                                 1                               1
#
#   Participation rate ;  > Males ; Participation rate ;  > Females ;
# 0                         Percent                           Percent
# 1             Seasonally Adjusted               Seasonally Adjusted
# 2                         PERCENT                           PERCENT
# 3                           Month                             Month
# 4                               1                                 1
#
# [5 rows x 22 columns]

# %%
EmploymentByState_NorthernTerritory_Original.shape
# Out:
# (585, 22)

# %%
EmploymentByState_NorthernTerritory_Original.iloc[:9]
# Out:
#          Unnamed: 0 Employed total ;  Persons ; Employed total ;  > Males ;  \
# 0              Unit                         000                         000
# 1       Series Type         Seasonally Adjusted         Seasonally Adjusted
# 2         Data Type                       STOCK                       STOCK
# 3         Frequency                       Month                       Month
# 4  Collection Month                           1                           1
# 5      Series Start         1978-02-01 00:00:00         1978-02-01 00:00:00
# 6        Series End         2026-01-01 00:00:00         2026-01-01 00:00:00
# 7           No. Obs                         576                         576
# 8         Series ID                  A84423335F                  A84423223L
#
#   Employed total ;  > Females ; > Employed full-time ;  Persons ;  \
# 0                           000                               000
# 1           Seasonally Adjusted               Seasonally Adjusted
# 2                         STOCK                             STOCK
# 3                         Month                             Month
# 4                             1                                 1
# 5           1978-02-01 00:00:00               1978-02-01 00:00:00
# 6           2026-01-01 00:00:00               2026-01-01 00:00:00
# 7                           576                               576
# 8                    A84423447X                        A84423343F
#
#   > Employed full-time ;  > Males ; > Employed full-time ;  > Females ;  \
# 0                               000                                 000
# 1               Seasonally Adjusted                 Seasonally Adjusted
# 2                             STOCK                               STOCK
# 3                             Month                               Month
# 4                                 1                                   1
# 5               1978-02-01 00:00:00                 1978-02-01 00:00:00
# 6               2026-01-01 00:00:00                 2026-01-01 00:00:00
# 7                               576                                 576
# 8                        A84423231L                          A84423455X
#
#   Employment to population ratio ;  Persons ;  \
# 0                                     Percent
# 1                         Seasonally Adjusted
# 2                                     PERCENT
# 3                                       Month
# 4                                           1
# 5                         1978-02-01 00:00:00
# 6                         2026-01-01 00:00:00
# 7                                         576
# 8                                  A84423342C
#
#   Employment to population ratio ;  > Males ;  \
# 0                                     Percent
# 1                         Seasonally Adjusted
# 2                                     PERCENT
# 3                                       Month
# 4                                           1
# 5                         1978-02-01 00:00:00
# 6                         2026-01-01 00:00:00
# 7                                         576
# 8                                  A84423230K
#
#   Employment to population ratio ;  > Females ;  ...  \
# 0                                       Percent  ...
# 1                           Seasonally Adjusted  ...
# 2                                       PERCENT  ...
# 3                                         Month  ...
# 4                                             1  ...
# 5                           1978-02-01 00:00:00  ...
# 6                           2026-01-01 00:00:00  ...
# 7                                           576  ...
# 8                                    A84423454W  ...
#
#   Unemployed total ;  > Females ; Unemployment rate ;  Persons ;  \
# 0                             000                        Percent
# 1             Seasonally Adjusted            Seasonally Adjusted
# 2                           STOCK                        PERCENT
# 3                           Month                          Month
# 4                               1                              1
# 5             1978-02-01 00:00:00            1978-02-01 00:00:00
# 6             2026-01-01 00:00:00            2026-01-01 00:00:00
# 7                             576                            576
# 8                      A84423448A                     A84423340X
#
#   Unemployment rate ;  > Males ; Unemployment rate ;  > Females ;  \
# 0                        Percent                          Percent
# 1            Seasonally Adjusted              Seasonally Adjusted
# 2                        PERCENT                          PERCENT
# 3                          Month                            Month
# 4                              1                                1
# 5            1978-02-01 00:00:00              1978-02-01 00:00:00
# 6            2026-01-01 00:00:00              2026-01-01 00:00:00
# 7                            576                              576
# 8                     A84423228X                       A84423452T
#
#   Labour force total ;  Persons ; Labour force total ;  > Males ;  \
# 0                             000                             000
# 1             Seasonally Adjusted             Seasonally Adjusted
# 2                           STOCK                           STOCK
# 3                           Month                           Month
# 4                               1                               1
# 5             1978-02-01 00:00:00             1978-02-01 00:00:00
# 6             2026-01-01 00:00:00             2026-01-01 00:00:00
# 7                             576                             576
# 8                      A84423337K                      A84423225T
#
#   Labour force total ;  > Females ; Participation rate ;  Persons ;  \
# 0                               000                         Percent
# 1               Seasonally Adjusted             Seasonally Adjusted
# 2                             STOCK                         PERCENT
# 3                             Month                           Month
# 4                                 1                               1
# 5               1978-02-01 00:00:00             1978-02-01 00:00:00
# 6               2026-01-01 00:00:00             2026-01-01 00:00:00
# 7                               576                             576
# 8                        A84423449C                      A84423341A
#
#   Participation rate ;  > Males ; Participation rate ;  > Females ;
# 0                         Percent                           Percent
# 1             Seasonally Adjusted               Seasonally Adjusted
# 2                         PERCENT                           PERCENT
# 3                           Month                             Month
# 4                               1                                 1
# 5             1978-02-01 00:00:00               1978-02-01 00:00:00
# 6             2026-01-01 00:00:00               2026-01-01 00:00:00
# 7                             576                               576
# 8                      A84423229A                        A84423453V
#
# [9 rows x 22 columns]

# %% [markdown]
# #### Step1. Turn the first to eighth row index into mata data

# %%
NorthTerritory_metadata = extract_matadata(EmploymentByState_NorthernTerritory_Original)
NorthTerritory_metadata.head()
# Out:
#                variable   gender unit          series_type data_type  \
# 0        Employed total  Persons  000  Seasonally Adjusted     STOCK
# 1        Employed total    Males  000  Seasonally Adjusted     STOCK
# 2        Employed total  Females  000  Seasonally Adjusted     STOCK
# 3  > Employed full-time  Persons  000  Seasonally Adjusted     STOCK
# 4  > Employed full-time    Males  000  Seasonally Adjusted     STOCK
#
#   frequency collection_month         series_start           series_end no_obs  \
# 0     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 1     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 2     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 3     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
# 4     Month                1  1978-02-01 00:00:00  2026-01-01 00:00:00    576
#
#     series_id
# 0  A84423335F
# 1  A84423223L
# 2  A84423447X
# 3  A84423343F
# 4  A84423231L

# %% [markdown]
# #### Step2. use series ID as column, prepare to melt the rest of dataset including series id, date, and values

# %%
# check if series_id has no duplicate
duplicate_rows = NorthTerritory_metadata[NorthTerritory_metadata.duplicated(subset=['series_id'], keep=False)]
duplicate_rows.shape
# Out:
# (0, 11)

# %%
value_melted = melt_and_update_columns(EmploymentByState_NorthernTerritory_Original)
value_melted
# Out:
#             date   series_id      value
# 0     1978-02-01  A84423335F  41.624292
# 1     1978-03-01  A84423335F  45.341661
# 2     1978-04-01  A84423335F  44.021738
# 3     1978-05-01  A84423335F  45.769913
# 4     1978-06-01  A84423335F  42.605502
# ...          ...         ...        ...
# 12091 2025-09-01  A84423453V  72.001683
# 12092 2025-10-01  A84423453V  71.069717
# 12093 2025-11-01  A84423453V  71.838167
# 12094 2025-12-01  A84423453V  72.496493
# 12095 2026-01-01  A84423453V  72.019522
#
# [12096 rows x 3 columns]

# %% [markdown]
# #### Step3. join part of metadata and values by series_id

# %%
# select the variables in the matadata
selected_columns = ['variable', 'gender', 'series_type', 'series_id']
order = ['date','series_id', 'variable', 'gender', 'series_type', 'value']

# merge
final_dataset = merge_metadata_and_melted_dataset(
    metadata = NorthTerritory_metadata,
    melted_dataset = value_melted,
    selected_columns = selected_columns
)

# reorder columns
final_dataset = final_dataset[order]

# print
final_dataset.head()
# Out:
#         date   series_id        variable   gender          series_type  \
# 0 1978-02-01  A84423335F  Employed total  Persons  Seasonally Adjusted
# 1 1978-03-01  A84423335F  Employed total  Persons  Seasonally Adjusted
# 2 1978-04-01  A84423335F  Employed total  Persons  Seasonally Adjusted
# 3 1978-05-01  A84423335F  Employed total  Persons  Seasonally Adjusted
# 4 1978-06-01  A84423335F  Employed total  Persons  Seasonally Adjusted
#
#        value
# 0  41.624292
# 1  45.341661
# 2  44.021738
# 3  45.769913
# 4  42.605502

# %% [markdown]
# ### Labor force status and growth change

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
LabourForce_CurrentOriginal.head()

# %% [markdown]
# #### Data Reframe plan

# %% [markdown]
# 1. Remove uneccessary rows and rename the columns\
# 2. Extract Month and year

# %% [markdown]
# #### 1. Remove uneccessary rows and rename the columns

# %%
# make a copy
LabourForce_Current = LabourForce_CurrentOriginal.copy()

# %%
LabourForce_Current_PreColNames = LabourForce_Current.columns
LabourForce_Current_NewColNames = LabourForce_Current.iloc[2].to_numpy()

# %%
LabourForce_Current_RemoveRows = LabourForce_Current.iloc[3:,:7]
LabourForce_Current_RemoveRows.head()

# %%
LabourForce_Current_RenameColumnNames = LabourForce_Current_RemoveRows.rename(columns = {LabourForce_Current_PreColNames[0]:LabourForce_Current_NewColNames[0],
                                                                                         LabourForce_Current_PreColNames[1]:LabourForce_Current_NewColNames[1],
                                                                                         LabourForce_Current_PreColNames[2]:LabourForce_Current_NewColNames[2],
                                                                                         LabourForce_Current_PreColNames[3]:LabourForce_Current_NewColNames[3],
                                                                                         LabourForce_Current_PreColNames[4]:LabourForce_Current_NewColNames[4],
                                                                                         LabourForce_Current_PreColNames[5]:LabourForce_Current_NewColNames[5],
                                                                                         LabourForce_Current_PreColNames[6]:LabourForce_Current_NewColNames[6],
                                                                                        })

# %%
LabourForce_Current_RenameColumnNames = LabourForce_Current_RenameColumnNames.rename(columns = {"Month":"Date", "State and territory (STT): ASGS (2011)":"State", "Labour force status - current month":"status_current_month", "Labour force status - previous month":"status_previous_month", "Persons - current month ('000)":"value_current_month"})

# %%
LabourForce_Current_RenameColumnNames.head()

# %% [markdown]
# #### 2. Extract Month and year

# %%
LabourForce_Current_MonthYear = LabourForce_Current_RenameColumnNames.copy()

# %%
LabourForce_Current_MonthYear.dtypes

# %%
LabourForce_Current_MonthYear.head()

# %%
LabourForce_Current_MonthYear['Date'][3]

# %% [markdown]
# Observed a mix of object and datetime. The plan is to convert the column to actuall datetime formate

# %%
LabourForce_Current_MonthYear['Date'] = pd.to_datetime(LabourForce_Current_MonthYear['Date'])

# %%
# extract month and year
LabourForce_Current_MonthYear['Year'] = LabourForce_Current_MonthYear['Date'].dt.year
LabourForce_Current_MonthYear['Month'] = LabourForce_Current_MonthYear['Date'].dt.month

# %%
LabourForce_Current_MonthYear.head()

# %%
#Drop Date
LabourForce_Current_DateDroped = LabourForce_Current_MonthYear.drop('Date', axis=1)

# %%
LabourForce_Current = LabourForce_Current_DateDroped.copy()

# %% [markdown]
# ### Combine datasets

# %%
LabourForce_Current.columns

# %%
EmployPopulationRatial.columns

# %% [markdown]
# ## Archive Codes

# %% [markdown]
# ### Employment to population Ration

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
EmployPopulationRatial_Original

# %%
EmployPopulationRatial = EmployPopulationRatial_Original.copy()

# %% [markdown]
# Observation:\
# The size of the data set is 124X1. The only column is named Employment-to-population ratio. Under the column there are three sub-columns. The first column is datetime, and the rest are the numerical data. The last two rows are not the value of the datasets.

# %% [markdown]
# #### Data processing plan

# %% [markdown]
# Step1 - reset index and the column names.\
# Step2 - remove the last two rows.\
# Step3 - extract month and year.\
# Step4 - convert the datatypes of month and year to numeric.\
# Step5 - convert data in seasonally adjusted from percentage to decimal

# %% [markdown]
# #### Step1 - reset index and the column names.

# %%
EmployPopulationRatial_ResetIndex = EmployPopulationRatial.reset_index()

# %%
EmployPopulationRatial_ResetColumnName = EmployPopulationRatial_ResetIndex.copy()
EmployPopulationRatial_ResetColumnName.columns = EmployPopulationRatial_ResetColumnName.iloc[0].tolist()
EmployPopulationRatial_ResetColumnName = EmployPopulationRatial_ResetColumnName.iloc[1:]

# %%
OriginalColumnNames = EmployPopulationRatial_ResetColumnName.columns
EmployPopulationRatial_ResetColumnName = EmployPopulationRatial_ResetColumnName.rename(columns = {OriginalColumnNames[0]:'Date', OriginalColumnNames[1]:'Employment_Population_Ratio', OriginalColumnNames[2]:'Ratio_SeasonallyAdjusted'})

# %%
EmployPopulationRatial_ResetColumnName.head()

# %% [markdown]
# #### Step2 - remove the last two rows.

# %%
EmployPopulationRatial_RemovedRows = EmployPopulationRatial_ResetColumnName.iloc[:121] 
EmployPopulationRatial_RemovedRows

# %% [markdown]
# #### Step3 - extract month and year.

# %%
EmployPopulationRatial_ExtractMonthYear = EmployPopulationRatial_RemovedRows.copy()

# %%
MonthYear = EmployPopulationRatial_ExtractMonthYear['Date'].str.split('-', expand=True)

# %%
MonthYear.columns

# %%
EmployPopulationRatial_ExtractMonthYear['Month_Name'] = MonthYear[0]
EmployPopulationRatial_ExtractMonthYear['Year'] = '20' + MonthYear[1]

# %%
EmployPopulationRatial_ExtractMonthYear['Month'] = pd.to_datetime(EmployPopulationRatial_ExtractMonthYear['Month_Name'], format='%b').dt.month

# %%
# drop Date, Month_Name
EmployPopulationRatial = EmployPopulationRatial_ExtractMonthYear.drop(columns = ['Date', 'Month_Name'])

# %%
EmployPopulationRatial.head()

# %% [markdown]
# #### Step4 - convert the datatypes of month and year to numeric.

# %%
EmployPopulationRatial['Year'] = EmployPopulationRatial['Year'].astype(int)

# %%
EmployPopulationRatial['Month'] = EmployPopulationRatial['Month'].astype(int)

# %% [markdown]
# #### Step5 - convert data in seasonally adjusted from percentage to decimal

# %%
#convert string to float then transfrom the data
EmployPopulationRatial['Ratio_SeasonallyAdjusted'] = EmployPopulationRatial['Ratio_SeasonallyAdjusted'].astype(float)/100

# %%
#drop first column
EmployPopulationRatial_cleaned = EmployPopulationRatial[['Ratio_SeasonallyAdjusted', 'Year', 'Month']]

# %%
EmployPopulationRatial_cleaned.head(5)

# %% [markdown]
# ### CPI_MonthlyPath(Archive)

# %% [markdown]
# #### Observe and Analyse the dataset

# %%
CPI_MonthlyPath = CPI_MonthlyOriginal.copy()
CPI_MonthlyPath.head()

# %% [markdown]
# Observation:\
# Data set type - structural data, wide data sets
# Size - 30rows X 133 columns
# columns- first column contains the information of each rows without a column name which suppose to be the column names, including but not limited to Unit, series type, data type, etc. From the seconde column to the last column, the column name contains the industry, including all groups, non-alcoholic beverages, bread and cereal product, etc.
# Data types - the data sets contain categorical, numerical and datetime datasets

# %% [markdown]
# #### Data processing plan

# %% [markdown]
# Step1 - transfer the wide data to long.\
# Step2 - extract the industries info and name the column industry.\
# Step3 - extract the Month and Year information from the datetime (located in the first row originally), named as Month and Year.\
# Step4 - deleted the columns/information that is not neceessary, for example colleciton month, series start, etc.\

# %% [markdown]
# #### Step1 - transfer the wide data to long.

# %%
CPT_Wide = CPI_MonthlyPath.T

# %% [markdown]
# #### Step2 - extract the industries info and name the column industry.

# %%
CPT_Wide.head()

# %%
CPT_Wide_resetIndex = CPT_Wide.reset_index()

# %%
CPT_Wide_resetIndex.head()

# %%
#make first row as column name
CPT_Wide_resetIndex.columns = CPT_Wide_resetIndex.iloc[0]
CPT_DropFirstRow = CPT_Wide_resetIndex.drop(0, axis = 0)

# %%
#name the first column industry
firstColumnName = CPT_DropFirstRow.columns[0]
rename = 'Industry'
CPT_rename = CPT_DropFirstRow.rename(columns = {firstColumnName:rename})

# %%
#reset index
CPT_Wide_resetIndex = CPT_rename.reset_index(drop=True)

# %%
#extract the industry
CPT_Wide_resetIndex['Industry'] = CPT_Wide_resetIndex['Industry'].str.split(' ; ', expand=True)[1]

# %% [markdown]
# #### Step3 - extract the Month and Year information from the datetime (located in the first row originally), named as Month and Year.

# %%
CPT_Wide_resetIndex.columns[10:]

# %%
#Get the columns that are not CPT with dates
CPT_nonDateColumnNames = CPT_Wide_resetIndex.columns[:10].tolist()
CPT_nonDateColumnNames

# %%
#Melt the dataframe
CPT_MeltedDateTime = pd.melt(CPT_Wide_resetIndex, id_vars=CPT_nonDateColumnNames, var_name = 'DateTime', value_name = 'CPT_Changes')

# %%
CPT_MeltedDateTime.head()

# %%
CPT_MeltedDateTime.dtypes

# %%
CPT_MeltedDateTime['Year'] = CPT_MeltedDateTime['DateTime'].dt.year

# %%
CPT_MeltedDateTime['Month'] = CPT_MeltedDateTime['DateTime'].dt.month

# %%
CPT_MeltedDateTime.head()

# %%
CPT_MeltedDateTime.dtypes

# %% [markdown]
# #### Step4 - deleted the columns/information that is not neceessary, for example colleciton month, series start, etc.

# %%
CPT = CPT_MeltedDateTime.copy()

# %%
CPT['No. Obs'].unique()

# %% [markdown]
# Remove Unit, Series Type, Data Type, Frequency, Collection Month, No.Obs, because there is only one value in these columns

# %%
dropedColumns = ['Unit', 'Series Type', 'Data Type', 'Frequency', 'Collection Month', 'No. Obs']

# %%
CPT_DropedColumns = CPT.drop(columns = dropedColumns, axis = 1)

# %% [markdown]
# Also dropped Series Start, Series end and Series ID cause its not relavant to CPT changes. Dropped DateTime Cause we already have Year and Month

# %%
dropedColumns = ['Series Start', 'Series End', 'DateTime', 'Series ID']

# %%
CPT_DropedDates = CPT_DropedColumns.drop(columns = dropedColumns, axis = 1)

# %%
CPT_DropedDates.shape

# %%
CPT = CPT_DropedDates.copy()
